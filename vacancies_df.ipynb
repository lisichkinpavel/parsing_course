# %%
import pandas as pd

# %%
df_hh = pd.read_json(r'hh_vacancies.json')
df_hh
# Out:
#                                              vacancy  \
# 0                            Системный администратор
# 1                    Системный администратор/ DevOps
# 2                            Системный администратор
# 3                            Системный администратор
# 4                    Системный администратор Windows
# ...                                              ...
# 1995     Системный администратор/Интернет-маркетолог
# 1996  Системный администратор (Рено-центр Ульяновск)
# 1997                         Системный администратор
# 1998                 Ведущий системный администратор
# 1999                 Ведущий системный администратор
#
#                                                     url  min_salary  \
# 0     https://hh.ru/vacancy/38059810?query=%D0%A1%D0...    150000.0
# 1     https://hh.ru/vacancy/37439768?query=%D0%A1%D0...         NaN
# 2     https://hh.ru/vacancy/38129294?query=%D0%A1%D0...     95000.0
# ...

# %%
df_sj = pd.read_json(r'superjob_vacancies.json')
df_sj
# Out:
#                                         vacancy  \
# 0                       Системный администратор
# 1     Системный администратор (ведущий инженер)
# 2     Системный Администратор (в п. Новая Чара)
# 3                       Системный администратор
# 4        Системный администратор, IT-специалист
# ..                                          ...
# 282                                  IT-инженер
# 283                               IT-специалист
# 284                              DevOps-инженер
# 285                        Специалист IT-отдела
# 286  IT-руководитель, администратор, специалист
#
#                                                    url  min_salary  \
# 0    https://russia.superjob.ru/vakansii/sistemnyj-...         NaN
# 1    https://russia.superjob.ru/vakansii/sistemnyj-...         NaN
# 2    https://russia.superjob.ru/vakansii/sistemnyj-...         NaN
# 3    https://russia.superjob.ru/vakansii/sistemnyj-...     60000.0
# ...

# %%
df= pd.concat([df_hh, df_sj], ignore_index=True)
df
# Out:
#                                          vacancy  \
# 0                        Системный администратор
# 1                Системный администратор/ DevOps
# 2                        Системный администратор
# 3                        Системный администратор
# 4                Системный администратор Windows
# ...                                          ...
# 2282                                  IT-инженер
# 2283                               IT-специалист
# 2284                              DevOps-инженер
# 2285                        Специалист IT-отдела
# 2286  IT-руководитель, администратор, специалист
#
#                                                     url  min_salary  \
# 0     https://hh.ru/vacancy/38059810?query=%D0%A1%D0...    150000.0
# 1     https://hh.ru/vacancy/37439768?query=%D0%A1%D0...         NaN
# 2     https://hh.ru/vacancy/38129294?query=%D0%A1%D0...     95000.0
# 3     https://hh.ru/vacancy/38121685?query=%D0%A1%D0...     75000.0
# ...
